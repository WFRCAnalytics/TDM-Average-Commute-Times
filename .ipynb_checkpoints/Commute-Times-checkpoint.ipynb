# %%
import pandas as pd
import os
import openmatrix as omx
pd.options.display.float_format = '{:,.2f}'.format
zWFRCMax = 2216

# %%
_pmskm_filename = r"A:\1 - TDM\3 - Model Dev\1 - WF\2 - Sandbox\v9.0Beta\WF TDM v9.0 - 2022-12-19\Scenarios\_PerformanceMeasures\PMSkims\RTP_2050_SkmPM.omx"
_amskm_filename = r"A:\1 - TDM\3 - Model Dev\1 - WF\2 - Sandbox\v9.0Beta\WF TDM v9.0 - 2022-12-19\Scenarios\_PerformanceMeasures\PMSkims\RTP_2050_SkmAM.omx"

dImportTabs = ['GP_TotTime']

print(_pmskm_filename)

myMatrixAM = omx.open_file(_amskm_filename)
myMatrixPM = omx.open_file(_pmskm_filename)

nMatrices = len(myMatrixAM)
nZones =  myMatrixAM.shape()[0] # always same number of i and j zones
matNames = myMatrixAM.list_matrices()

dictionary_list = []

#read and print all data
for m in range(nMatrices):
    if matNames[m] in dImportTabs:
        print("Matrix: %s" %matNames[m])
        _mAM = myMatrixAM[matNames[m]]
        _mPM = myMatrixPM[matNames[m]]
        for r in range(nZones):
            if r % 100==0:
                print (r)
            for c in range (nZones):
                if r < zWFRCMax or c < zWFRCMax:
                    if _mPM[r,c] > 0:
                        dictionary_data = { 'tablPMPk' : matNames[m] ,
                                            'oTAZ'     : r+1         , # TAZ ID is one more than index
                                            'dTAZ'     : c+1         ,                
                                            'valueAMPk': _mAM[r,c]   ,  # get maximum value in row from AM matrix
                                            'valuePMPk': _mPM[r,c]      # get maximum value in row from PM matrix
                                           }
                        dictionary_list.append(dictionary_data)

dfTime = pd.DataFrame.from_dict(dictionary_list)
dictionary_list = []
dfTime
# Out:
# A:\1 - TDM\3 - Model Dev\1 - WF\2 - Sandbox\v9.0Beta\WF TDM v9.0 - 2022-12-19\Scenarios\_PerformanceMeasures\PMSkims\RTP_2050_SkmPM.omx
# Matrix: GP_TotTime
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
#             tablPMPk  oTAZ  dTAZ  valueAMPk  valuePMPk
# 0         GP_TotTime     1     1       3.43       3.43
# 1         GP_TotTime     1     2       2.99       2.99
# 2         GP_TotTime     1     3      18.46      18.85
# 3         GP_TotTime     1     4      19.52      19.90
# 4         GP_TotTime     1     5       4.86       4.86
# ...              ...   ...   ...        ...        ...
# 11173067  GP_TotTime  3629  2212      89.03      87.15
# 11173068  GP_TotTime  3629  2213      91.85      89.98
# 11173069  GP_TotTime  3629  2214     103.47     103.29
# 11173070  GP_TotTime  3629  2215      91.96      90.08
# 11173071  GP_TotTime  3629  2216      88.47      86.60
#
# [11173072 rows x 5 columns]

# %%
dfTime = dfPMPk
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-2c0f4833cc67> in <module>
# ----> 1 dfTime = dfPMPk
#
# NameError: name 'dfPMPk' is not defined

# %%
_hbwtrip_filename = r"A:\1 - TDM\3 - Model Dev\1 - WF\2 - Sandbox\v9.0Beta\WF TDM v9.0 - 2022-12-19\Scenarios\RTP_2050\4_ModeChoice\2_DetailedTripMatrices\HBW_trips_allsegs_Pk.omx"

dImportTabs = ['auto']

print(_hbwtrip_filename)

myMatrix = omx.open_file(_hbwtrip_filename)

nMatrices = len(myMatrix)
nZones =  myMatrix.shape()[0] # always same number of i and j zones
matNames = myMatrix.list_matrices()

dictionary_list_2 = []

#read and print all data
for m in range(nMatrices):
    if matNames[m] in dImportTabs:
        print("Matrix: %s" %matNames[m])
        _m = myMatrix[matNames[m]]
        for r in range(nZones):
            if r % 100==0:
                print (r)
            for c in range (nZones):
                if r < zWFRCMax or c < zWFRCMax:
                    if _m[r,c] > 0:
                        dictionary_data = { 'tabHBW'  : matNames[m] ,
                                            'oTAZ'    : r+1         , # TAZ ID is one more than index
                                            'dTAZ'    : c+1         ,                
                                            'valueHBW': _m[r,c]  # get maximum value in row
                                           }
                        dictionary_list_2.append(dictionary_data)
                    
dfHBWTrips = pd.DataFrame.from_dict(dictionary_list_2)
dictionary_list_2 = []
dfHBWTrips
# Out:
# A:\1 - TDM\3 - Model Dev\1 - WF\2 - Sandbox\v9.0Beta\WF TDM v9.0 - 2022-12-19\Scenarios\RTP_2050\4_ModeChoice\2_DetailedTripMatrices\HBW_trips_allsegs_Pk.omx
# Matrix: auto
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
#         tabHBW  oTAZ  dTAZ  valueHBW
# 0         auto     2     5     18.42
# 1         auto     2     6      1.93
# 2         auto     2     7     29.20
# 3         auto     2     8     20.75
# 4         auto     2     9     18.61
# ...        ...   ...   ...       ...
# 4071703   auto  3629  2184      2.00
# 4071704   auto  3629  2185      5.00
# 4071705   auto  3629  2186      4.92
# 4071706   auto  3629  2196      1.00
# 4071707   auto  3629  2197      3.00
#
# [4071708 rows x 4 columns]

# %%
dfCombo = pd.DataFrame.merge(dfTime,dfHBWTrips,on=('oTAZ','dTAZ'))
#dfCombo = dfCombo[dfCombo['valuePMPk']<valuePMPk]
dfCombo
# Out:
#            tablPMPk  oTAZ  dTAZ  valueAMPk  valuePMPk tabHBW  valueHBW
# 0        GP_TotTime     2     5       4.30       4.30   auto     18.42
# 1        GP_TotTime     2     6      17.56      17.95   auto      1.93
# 2        GP_TotTime     2     7      17.81      18.19   auto     29.20
# 3        GP_TotTime     2     8       7.52       7.52   auto     20.75
# 4        GP_TotTime     2     9      15.05      15.43   auto     18.61
# ...             ...   ...   ...        ...        ...    ...       ...
# 4071703  GP_TotTime  3629  2184      60.47      56.42   auto      2.00
# 4071704  GP_TotTime  3629  2185      60.38      57.00   auto      5.00
# 4071705  GP_TotTime  3629  2186      62.32      60.04   auto      4.92
# 4071706  GP_TotTime  3629  2196      89.02      87.15   auto      1.00
# 4071707  GP_TotTime  3629  2197      87.52      85.65   auto      3.00
#
# [4071708 rows x 7 columns]

# %%
dfCombo['AMPk_PMPk_x_HBW'] = (dfCombo['valueAMPk'] + dfCombo['valuePMPk'] ) * dfCombo['valueHBW']
dfCombo
# Out:
#            tablPMPk  oTAZ  dTAZ  valueAMPk  valuePMPk tabHBW  valueHBW  \
# 0        GP_TotTime     2     5       4.30       4.30   auto     18.42
# 1        GP_TotTime     2     6      17.56      17.95   auto      1.93
# 2        GP_TotTime     2     7      17.81      18.19   auto     29.20
# 3        GP_TotTime     2     8       7.52       7.52   auto     20.75
# 4        GP_TotTime     2     9      15.05      15.43   auto     18.61
# ...             ...   ...   ...        ...        ...    ...       ...
# 4071703  GP_TotTime  3629  2184      60.47      56.42   auto      2.00
# 4071704  GP_TotTime  3629  2185      60.38      57.00   auto      5.00
# 4071705  GP_TotTime  3629  2186      62.32      60.04   auto      4.92
# 4071706  GP_TotTime  3629  2196      89.02      87.15   auto      1.00
# 4071707  GP_TotTime  3629  2197      87.52      85.65   auto      3.00
#
#          AMPk_PMPk_x_HBW
# 0                 158.41
# 1                  68.53
# 2               1,051.20
# 3                 312.08
# 4                 567.23
# ...                  ...
# 4071703           233.78
# 4071704           586.90
# 4071705           602.01
# 4071706           176.17
# 4071707           519.51
#
# [4071708 rows x 8 columns]

# %%
# round to two decimal places in python pandas
dWFRCTotals = dfCombo[['valueHBW','AMPk_PMPk_x_HBW']].sum()
dWFRCTotals
# Out:
# valueHBW            114,763,329.35
# AMPk_PMPk_x_HBW   5,481,648,152.94
# dtype: float64

# %%
dWFRCTotals[1] / dWFRCTotals[0]
# Out:
# 47.7648059183323

# %%
dfTime.hist(bins=3)
# Out:
# array([[<AxesSubplot:title={'center':'oTAZ'}>,
#         <AxesSubplot:title={'center':'dTAZ'}>],
#        [<AxesSubplot:title={'center':'valueAMPk'}>,
#         <AxesSubplot:title={'center':'valuePMPk'}>]], dtype=object)
